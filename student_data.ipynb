# %% [markdown]
# #### PF theory project Data of Students

# %% [markdown]
# #### Name : Abdul Rehman
# #### Roll No "052"

# %% [markdown]
# ##### Import Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("students_data.csv")

# %%
df.columns
# Out:
# Index(['cgpa', 'iq'], dtype='object')

# %%
df.head(2)
# Out:
#    cgpa   iq
# 0  5.13   88
# 1  5.90  113

# %%
df.tail(2)
# Out:
#      cgpa   iq
# 198  6.23  108
# 199  8.82  117

# %%
df.shape
# Out:
# (200, 2)

# %% [markdown]
# ##### Randomly pick Data

# %%
df.sample(2)
# Out:
#      cgpa   iq
# 26   4.86   87
# 182  6.17  110

# %%
df.columns
# Out:
# Index(['cgpa', 'iq'], dtype='object')

# %%
df.rename(columns={"cgpa":"CGPA_Students","iq":"Students_IQ"},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CGPA_Students  200 non-null    float64
#  1   Students_IQ    200 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 3.3 KB

# %% [markdown]
# ##### Describe Data !

# %%
df.describe()
# Out:
#        CGPA_Students  Students_IQ
# count     200.000000   200.000000
# mean        6.983400   101.995000
# std         1.624101    12.161599
# min         4.600000    83.000000
# 25%         5.407500    91.000000
# 50%         7.040000   102.000000
# 75%         8.585000   113.000000
# max         9.300000   121.000000

# %%
a = df.describe(include = "all")

# %%
a.columns
# Out:
# Index(['CGPA_Students', 'Students_IQ'], dtype='object')

# %%
a.describe(include="all")
# Out:
#        CGPA_Students  Students_IQ
# count       8.000000     8.000000
# mean       30.442500   103.019575
# std        68.554039    51.589897
# min         1.624101    12.161599
# 25%         5.205625    89.000000
# 50%         7.011700   101.997500
# 75%         8.763750   115.000000
# max       200.000000   200.000000

# %% [markdown]
# ##### (LOC) Used

# %%
a.loc[["count","mean"]]
# Out:
#        CGPA_Students  Students_IQ
# count       200.0000      200.000
# mean          6.9834      101.995

# %%
a.iloc[[0,1,2]]
# Out:
#        CGPA_Students  Students_IQ
# count     200.000000   200.000000
# mean        6.983400   101.995000
# std         1.624101    12.161599

# %%
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)
df[["CGPA_Students","Students_IQ"]]
# Out:
#      CGPA_Students  Students_IQ
# 0             5.13           88
# 1             5.90          113
# 2             8.36           93
# 3             8.27           97
# 4             5.45          110
# 5             5.88          109
# 6             8.41           98
# 7             8.80          115
# 8             5.79          110
# 9             8.09           94
# 10            4.60           86
# 11            6.10          110
# 12            8.16           97
# 13            5.00           88
# 14            5.71          108
# 15            8.31           95
# 16            5.50          111
# 17            7.87           91
# 18            6.05          111
# 19            5.84          113
# 20            7.47           98
# 21            4.86           86
# 22            7.78           92
# 23            4.78           87
# 24            4.96           88
# 25            7.93           98
# 26            4.86           87
# 27            9.18          119
# ...

# %%
df.columns
# Out:
# Index(['CGPA_Students', 'Students_IQ'], dtype='object')

# %% [markdown]
# ##### Mean !

# %%
df["CGPA_Students"].mean()
# Out:
# 6.9834000000000005

# %% [markdown]
# ##### Median

# %%
df["CGPA_Students"].median()
# Out:
# 7.04

# %% [markdown]
# ##### Mode

# %%
df["CGPA_Students"].mode()
# Out:
# 0    8.91
# Name: CGPA_Students, dtype: float64

# %% [markdown]
# #### For count the values

# %%
df[["CGPA_Students"]].value_counts()
# Out:
# CGPA_Students
# 8.91             4
# 4.86             3
# 6.05             3
# 5.01             3
# 8.86             3
# 8.97             3
# 4.98             3
# 5.74             3
# 4.78             3
# 5.85             2
# 8.40             2
# 6.01             2
# 5.32             2
# 6.10             2
# 5.91             2
# 5.88             2
# 8.81             2
# 5.87             2
# 8.79             2
# 5.67             2
# 8.78             2
# 5.15             2
# 5.80             2
# 8.72             2
# 5.20             2
# 8.14             2
# 8.08             2
# 7.93             2
# 4.89             2
# 8.94             2
# 8.25             2
# 4.95             2
# 4.96             2
# 9.03             2
# 8.23             2
# 4.76             2
# 5.05             2
# 4.68             2
# 8.20             1
# 8.54             1
# 8.18             1
# 8.53             1
# 8.56             1
# 8.21             1
# 8.46             1
# 8.30             1
# ...

# %%
df.columns
# Out:
# Index(['CGPA_Students', 'Students_IQ'], dtype='object')

# %%
df[["Students_IQ"]].value_counts().plot(kind="bar",title="CGPA_OF_Students",color="black")
# Out:
# <Axes: title={'center': 'CGPA_OF_Students'}, xlabel='Students_IQ'>

# %% [markdown]
# ##### Graphs

# %%
df[["CGPA_Students"]].value_counts().plot(kind="hist",title="CGPA_OF_Students",color="blue")
# Out:
# <Axes: title={'center': 'CGPA_OF_Students'}, ylabel='Frequency'>

# %%
df[["Students_IQ"]].value_counts().plot(kind="pie",title="CGPA_OF_Students",color="blue")
# Out:
# <Axes: title={'center': 'CGPA_OF_Students'}, ylabel='count'>

# %% [markdown]
# ##### Is.null

# %%
df.isnull().sum()
# Out:
# CGPA_Students    0
# Students_IQ      0
# dtype: int64

# %%
df[df["Students_IQ"].isnull()]
# Out:
# Empty DataFrame
# Columns: [CGPA_Students, Students_IQ]
# Index: []

# %%
df["Final_Students_IQ"] = df["Students_IQ"].fillna(df["Students_IQ"].mean())

# %%
df[df["Final_Students_IQ"].isnull()]
# Out:
# Empty DataFrame
# Columns: [CGPA_Students, Students_IQ, Final_Students_IQ]
# Index: []

# %%
df.groupby("Final_Students_IQ").describe()
# Out:
#                   CGPA_Students                                           \
#                           count      mean       std   min     25%    50%
# Final_Students_IQ
# 83                          3.0  5.143333  0.135031  5.01  5.0750  5.140
# 84                          1.0  5.440000       NaN  5.44  5.4400  5.440
# 85                          8.0  4.997500  0.204503  4.78  4.8700  4.905
# 86                         11.0  4.905455  0.195262  4.60  4.8100  4.880
# 87                          9.0  4.927778  0.165890  4.68  4.7800  4.980
# 88                         12.0  4.990000  0.147217  4.79  4.8850  4.965
# 89                          4.0  4.900000  0.232092  4.68  4.7400  4.860
# 90                          1.0  4.760000       NaN  4.76  4.7600  4.760
# 91                          5.0  7.496000  1.414860  4.98  7.8700  8.140
# 92                          5.0  8.204000  0.356272  7.78  7.9900  8.200
# 93                          8.0  8.283750  0.209553  7.91  8.2300  8.355
# ...

# %% [markdown]
# ##### File save for new name !

# %%
df.to_csv("Studets_Data02.csv")
